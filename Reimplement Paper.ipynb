# %% [markdown]
# **IMPLEMENT *AStrong Baseline for Vehicle Re-Identification* PAPER ON MARKET1501 DATASET**

# %% [markdown]
# # ======================= D A T A   D O W N L O A D =========================

# %%
# Download Market-1501 Dataset
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1ozb7D2cvc-TKVlLVCdYNWmTgZzEvNT4R' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1ozb7D2cvc-TKVlLVCdYNWmTgZzEvNT4R" -O /content/market\ 1501.zip && rm -rf /tmp/cookies.txt
# Out:
# --2022-08-03 05:26:40--  https://docs.google.com/uc?export=download&confirm=t&id=1ozb7D2cvc-TKVlLVCdYNWmTgZzEvNT4R
# Resolving docs.google.com (docs.google.com)... 142.250.97.113, 142.250.97.102, 142.250.97.100, ...
# Connecting to docs.google.com (docs.google.com)|142.250.97.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-00-bs-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/71263dcd7uldj5m0493r8thludk5skaq/1659504375000/02375505794862658516/*/1ozb7D2cvc-TKVlLVCdYNWmTgZzEvNT4R?e=download&uuid=c8ace14a-a2d1-45be-9da2-3c6144df9798 [following]
# ...
# --2022-08-03 05:26:40--  https://doc-00-bs-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/71263dcd7uldj5m0493r8thludk5skaq/1659504375000/02375505794862658516/*/1ozb7D2cvc-TKVlLVCdYNWmTgZzEvNT4R?e=download&uuid=c8ace14a-a2d1-45be-9da2-3c6144df9798
# ...

# %%
# !mkdir -p '/content/data/raw/'

# %%
# Extract Market Dataset
# !unzip -qq '/content/market 1501.zip' -d '/content/data/raw/'

# %%
# Data Cleaning - Fix file names
# !find '/content/data/raw/Market-1501-v15.09.15' -name "*.jpg.jpg" -exec rename -v 's/\.jpg.jpg$/\.jpg/i' {} \;
# Out:
# /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c1s6_023021_00.jpg.jpg renamed as /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c1s6_023021_00.jpg
# /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c1s6_023071_00.jpg.jpg renamed as /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c1s6_023071_00.jpg
# /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c2s3_065527_00.jpg.jpg renamed as /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c2s3_065527_00.jpg
# /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c2s3_065552_00.jpg.jpg renamed as /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c2s3_065552_00.jpg
# /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c3s3_071344_00.jpg.jpg renamed as /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c3s3_071344_00.jpg
# /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c3s3_071369_00.jpg.jpg renamed as /content/data/raw/Market-1501-v15.09.15/gt_bbox/1488_c3s3_071369_00.jpg
# ...

# %% [markdown]
# =================================================================================================================

# %%
# !pip install yacs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd '/content/drive/MyDrive/Research'
# Out:
# /content/drive/MyDrive/Research

# %% [markdown]
# *Note*: turn-off FP16 training by setting SOLVER.FP16=False

# %%
# !python -W ignore  train.py --config_file='configs/config.yml'
# Out:
# 2022-08-03 05:32:26,948 reid_baseline INFO: Using 1 GPUS
# 2022-08-03 05:32:26,948 reid_baseline INFO: Namespace(config_file='configs/config.yml', opts=[])
# 2022-08-03 05:32:26,948 reid_baseline INFO: Loaded configuration file configs/config.yml
# 2022-08-03 05:32:26,949 reid_baseline INFO: Running with config:
# DATALOADER:
#   NUM_INSTANCE: 8
#   NUM_WORKERS: 4
#   SAMPLER: softmax_triplet
# DATASETS:
#   COMBINEALL: False
#   ROOT_DIR: /content/data/raw/
#   TEST: ('market1501',)
#   TRAIN: ('market1501',)
# INPUT:
#   AUGMIX_PROB: 0.25
#   COLORJIT_PROB: 0.25
#   COLOR_SPACE: rgb
#   CUTOFF_LONGTAILED: False
#   LONGTAILED_THR: 2
#   PADDING: 10
#   PIXEL_MEAN: [0.485, 0.456, 0.406]
#   PIXEL_STD: [0.229, 0.224, 0.225]
#   PROB: 0.5
#   RANDOM_AFFINE_PROB: 0.25
#   RANDOM_BLUR_PROB: 0.25
#   RANDOM_PATCH_PROB: 0.25
#   RE_PROB: 0.5
#   RE_SH: 0.4
#   SIZE_TEST: [320, 320]
#   SIZE_TRAIN: [320, 320]
#   VERTICAL_FLIP_PROB: 0.0
# MODEL:
#   DEVICE: cuda
#   DEVICE_ID: 0
# ...
